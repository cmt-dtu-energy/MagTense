# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
mu0 = 4 * np.pi * 1e-7
Ms = 1.61 / mu0

# %%
#res_path = "../figs/Grid_rasBase_5_nGrains_5_nRef_3_dG_5e-09_cuda_sparse.npz"



#res_path = "../figs/Grid_rasBase_5_nGrains_5_nRef_3_dG_5e-09_fmm_eps1.00e-04_cpn200.npz"
#res_path = "../figs/Grid_rasBase_5_nGrains_5_nRef_3_dG_5e-09_fmm_eps1.00e-04_cpn400.npz"
#res_path = "../figs/Grid_rasBase_5_nGrains_5_nRef_3_dG_5e-09_fmm_eps1.00e-04_cpn600.npz"


#res_path = "../figs/Grid_rasBase_5_nGrains_5_nRef_4_dG_3.75e-09_fmm_eps1.00e-04_cpn600.npz"

#res_path = "../figs/Grid_rasBase_5_nGrains_5_nRef_3_dG_5e-09_fmm_eps1.00e-04_cpn1000.npz"


#res_path = "../figs/Grid_rasBase_5_nGrains_5_nRef_3_dG_5e-09_fmm_eps1.00e-04_cpn1000_pure.npz"
#res_path = "../figs/Grid_rasBase_5_nGrains_5_nRef_3_dG_5e-09_fmm_eps1.00e-04_cpn1000_fmm.npz"



#res_path = "../figs/Grid_rasBase_5_nGrains_25_nRef_4_dG_3.75e-09_fmm_eps1.00e-04_cpn120.npz"
#res_path = "../figs/Grid_rasBase_5_nGrains_25_nRef_4_dG_3.75e-09_fmm_eps1.00e-04_cpn660.npz"




#res_path = "../figs_old/Grid_rasBase_5_nGrains_25_nRef_4_dG_3.75e-09_cuda.npz"
#res_path = "../figs_old/Grid_rasBase_5_nGrains_5_nRef_4_dG_3.75e-09_cuda.npz"
#res_path = "../figs_old/Grid_rasBase_5_nGrains_5_nRef_3_dG_5e-09_cuda.npz"

res_path = "../figs/Grid_rasBase_5_nGrains_25_nRef_4_dG_3.75e-09_fmm_eps1.00e-04_cpn200.npz"
#res_path = "../figs/Grid_rasBase_5_nGrains_25_nRef_4_dG_3.75e-09_cuda.npz"


data = np.load(res_path, allow_pickle=True)

res = data["res"]       # full Micromag result object
M = res[1][1,:,:,:]
BH_max = float(data["BH_max"])
H_star = float(data["H_star"])
B_star = float(data["B_star"])
M_star = float(data["M_star"])
Hc = float(data["Hc"])
H_N = float(data["H_N"])
runtime = float(data["runtime"])
H_array = data["H_array"]
M_array = data["M_array"]

print(" number of points = ", M.shape[0])
print("runtime = ", runtime, " seconds")

# %%
H_exc, H_ext, H_dem, H_ani = res[3:7]
H_ext[0,1000,:,:]

# %%
mu0 = 4 * np.pi * 1e-7
Hyst_dir = np.array([0.0, 0.0, 1.0])
Ms = 1.61 / mu0   # [A/m]
K0 = 4.3e6        # [J/m^3]
h_ext_base = Hyst_dir / mu0
steps = np.arange(1.0, -7.0, -0.1)
H_ext = np.zeros((len(steps), 4))
H_ext[:, 0] = steps
H_ext[:, 1:4] = steps[:, np.newaxis] * h_ext_base

# %%
fig, ax = plt.subplots(figsize=(8, 4))

ax.plot(H_array, M_array / Ms, ".-k", linewidth=1.5, markersize=6, label="M/Ms")
ax.plot(Hc, 0.0, "r*", markersize=10, label="Hc")

ax.plot(H_star, M_star / Ms, "b*", markersize=10, label=r"$BH_{\max}$")

ax.set_xlabel("H [A/m]")
ax.set_ylabel("M/Ms [-]")
ax.set_title("Hysteresis Loop")
ax.grid(True, which="both", linestyle="--", linewidth=0.5)
ax.legend()

fig.tight_layout()
#fig.savefig(fig_path, dpi=300)
#print(f"Saved figure to: {fig_path}")

# %%
fig, ax = plt.subplots(figsize=(8, 4))

ax.plot(H_array, M_array / Ms, ".-k", linewidth=1.5, markersize=6, label="M/Ms")
ax.plot(Hc, 0.0, "r*", markersize=10, label="Hc")

ax.plot(H_star, M_star / Ms, "b*", markersize=10, label=r"$BH_{\max}$")

ax.set_xlabel("H [A/m]")
ax.set_ylabel("M/Ms [-]")
ax.set_title("Hysteresis Loop")
ax.grid(True, which="both", linestyle="--", linewidth=0.5)
ax.legend()

fig.tight_layout()
#fig.savefig(fig_path, dpi=300)
#print(f"Saved figure to: {fig_path}")
