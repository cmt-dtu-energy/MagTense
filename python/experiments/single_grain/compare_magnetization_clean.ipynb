# %%
from pathlib import Path

import matplotlib.pyplot as plt

# %matplotlib widget

from utils.magnetization import interactive_magnetization_file_selector_and_orientation_3d

# %%
# RESULTS_DIR = Path("results")
RESULTS_DIR = Path("res_fe16n2_Ms_2.4_A0_7e-12_K0_1e6/shape_ellipsoid_x/batch_20260617_074548_3_659460/results")
#RESULTS_DIR = Path("res_fe16n2_Ms_2.4_A0_7e-12_K0_1e6/shape_ellipsoid_z/batch_20260617_074548_4_659460/results")
#RESULTS_DIR = Path("res_fe16n2_Ms_2.4_A0_7e-12_K0_1e6/shape_sphere/batch_20260617_074548_2_659460/results")
#RESULTS_DIR = Path("res_fe16n2_Ms_2.4_A0_7e-12_K0_1e6/shape_cube/batch_20260617_074548_1_659460/results")

RESULT_PATTERN = "single_grain_*.npz"

# %%
plt.close("all")

controls = interactive_magnetization_file_selector_and_orientation_3d(
    results_dir=RESULTS_DIR,
    result_pattern=RESULT_PATTERN,
    size_factor_init=5,
    n_init=10,
    adaptive_init=True,
    periodic_init=False,
    adaptive_dh_min_t_init=0.001,
    target_H1_init=-0.9,
    target_H2_init=-1.0,
    use_unit_vectors=True,
    stride_init=1,
    vector_length_init=0.75,
    diff_vector_length_init=1.0,
    elev_init=60,
    azim_init=25,
    last_panel_init="difference",
    continuous_update=False,
)
